# %%
# results melgarejo
import re

filename = 'results_noTW.txt'
x = 0
sum_10 = 0
sum_20 = 0
sum_30 = 0
sum_50 = 0
sum_100 = 0 

with open(filename) as f:
    for line in f:
        if('matrix10' not in line and 'matrix20' not in line):
            #print(line)
            #print(line[:7])
            if(line[:7] == 'inst_10' and line[:8] != 'inst_100'):
                numbers = re.findall(r"\d+",line)
                rightnumber = [int(e) for e in numbers if int(e) > 1000]
                sum_10 += rightnumber[0]

            if(line[:7] == 'inst_20'):
                numbers = re.findall(r"\d+",line)
                rightnumber = [int(e) for e in numbers if int(e) > 1000]
                sum_20 += rightnumber[0]

            if(line[:7] == 'inst_30'):
                numbers = re.findall(r"\d+",line)
                rightnumber = [int(e) for e in numbers if int(e) > 1000]
                sum_30 += rightnumber[0]

            if(line[:7] == 'inst_50'):
                numbers = re.findall(r"\d+",line)
                rightnumber = [int(e) for e in numbers if int(e) > 1000]
                sum_50 += rightnumber[0]

            if(line[:8] == 'inst_100'):
                numbers = re.findall(r"\d+",line)
                rightnumber = [int(e) for e in numbers if int(e) > 1000]
                sum_100 += rightnumber[0]
                print(rightnumber[0])
            
print(sum_10,sum_20,sum_30,sum_50,sum_100)
# Out:
# 39249
# 36015
# 36807
# 39631
# 37377
# 38312
# 40371
# 39302
# 38189
# 40021
# 40486
# 41122
# 39439
# 38089
# 39826
# 39128
# 41595
# 39582
# 40032
# 40163
# 502287 784663 1020090 464237 784736

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#results Melgarejo

x = [10,20,30,50,100]
ychris = [0.135432532,0.125263967,0.130578674,0.136023195,0.158807548]
yfirst = [0.452020458,0.75541347,1.027636777,1.409622671,1.752464523]
yinsertion = [0.162060734,0.155295968,0.192284994,0.22584585,0.24301803]
yneighbor = [0.255901507,0.465780851,0.650857277,0.902332214,1.145023294]
ysavings = [0.033112543,0.045526551,0.036880079,0.039221346,0.047853036]

plt.plot(x,yinsertion,label ='Cheapest Insertion',marker= 's')
plt.plot(x,ychris, label='Christofides',marker='o')
plt.plot(x,yfirst,label= 'First Fit',marker='^')
plt.plot(x,yneighbor,label='Nearest Neighbour',marker='D')
plt.plot(x,ysavings,label='Savings',marker='X')

plt.xlabel('Number of vertices')
plt.ylabel('Excess over given solution')
plt.xticks([10,20,30,50,100])

plt.legend()
plt.savefig('diagrammMelgarejo.png')
plt.show()

# %%
from tabulate import tabulate
table = [['Heuristic','10 vertices','20 vertices','30 vertices','50 vertices','100 vertices'],['Cheapest Insertion',0.162060734,0.155295968,0.192284994,0.22584585,0.24301803],['Christofides',0.135432532,0.125263967,0.130578674,0.136023195,0.158807548],['First Fit',0.452020458,0.75541347,1.027636777,1.409622671,1.752464523],['Nearest Neighbor',0.255901507,0.465780851,0.650857277,0.902332214,1.145023294],['Savings',0.033112543,0.045526551,0.036880079,0.039221346,0.047853036]]
print(tabulate(table,headers = 'firstrow',tablefmt = 'fancy_grid'))
# Out:
# ╒════════════════════╤═══════════════╤═══════════════╤═══════════════╤═══════════════╤════════════════╕
# │ Heuristic          │   10 vertices │   20 vertices │   30 vertices │   50 vertices │   100 vertices │
# ╞════════════════════╪═══════════════╪═══════════════╪═══════════════╪═══════════════╪════════════════╡
# │ Cheapest Insertion │     0.162061  │     0.155296  │     0.192285  │     0.225846  │       0.243018 │
# ├────────────────────┼───────────────┼───────────────┼───────────────┼───────────────┼────────────────┤
# │ Christofides       │     0.135433  │     0.125264  │     0.130579  │     0.136023  │       0.158808 │
# ├────────────────────┼───────────────┼───────────────┼───────────────┼───────────────┼────────────────┤
# │ First Fit          │     0.45202   │     0.755413  │     1.02764   │     1.40962   │       1.75246  │
# ├────────────────────┼───────────────┼───────────────┼───────────────┼───────────────┼────────────────┤
# ...

# %%
#Cordeau depending on # of vertices
x = [15,20,25,30,35,40]
ychris = [1.069623038,1.080991089,1.089520368,1.067851482,1.124127688,1.082983138]
yfirst = [1.54362555,1.78716961,2.020089925,2.178750204,2.908923249,2.526910251]
yinsertion = [1.119311892,1.177339835,1.203925058,1.225444005,1.240823055,1.247994397]
yneighbor = [1.23396097,1.232572095,1.361091985,1.328705579,2.642754192,1.513504086]
ysavings = [1.006955316,1.004005971,1.000930203,1.000542377,1,1.00028626]

plt.plot(x,yinsertion,label ='Cheapest Insertion',marker= 's')
plt.plot(x,ychris, label='Christofides',marker='o')
plt.plot(x,yfirst,label= 'First Fit',marker='^')
plt.plot(x,yneighbor,label='Nearest Neighbour',marker='D')
plt.plot(x,ysavings,label='Savings',marker='X')

plt.xlabel('Number of vertices')
plt.ylabel('Result compared to best heuristic solution')
plt.xticks([15,20,25,30,35,40])

plt.legend()
plt.savefig('diagrammCordeau.png')
plt.show()

# %%
#Cordeau depending on # of vertices
x = [15,20,25,30,35,40]
ychris = [1.069623038,1.080991089,1.089520368,1.067851482,1.124127688,1.082983138]
yfirst = [1.54362555,1.78716961,2.020089925,2.178750204,2.908923249,2.526910251]
yinsertion = [1.23396097,1.232572095,1.361091985,1.328705579,2.642754192,1.513504086]
yneighbor = [1.119311892,1.177339835,1.203925058,1.225444005,1.240823055,1.247994397]
ysavings = [1.006955316,1.004005971,1.000930203,1.000542377,1,1.00028626]

plt.plot(x,yinsertion,label ='Cheapest Insertion',marker= 's')
plt.plot(x,ychris, label='Christofides',marker='o')
plt.plot(x,yfirst,label= 'First Fit',marker='^')
plt.plot(x,yneighbor,label='Nearest Neighbour',marker='D')
plt.plot(x,ysavings,label='Savings',marker='X')

plt.xlabel('Number of vertices')
plt.ylabel('Result compared to best heuristic solution')
plt.xticks([15,20,25,30,35,40])

plt.legend()
plt.savefig('diagrammCordeau.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-dc2e85d6d431> in <module>
#       7 ysavings = [1.006955316,1.004005971,1.000930203,1.000542377,1,1.00028626]
#       8
# ----> 9 plt.plot(x,yinsertion,label ='Cheapest Insertion',marker= 's')
#      10 plt.plot(x,ychris, label='Christofides',marker='o')
#      11 plt.plot(x,yfirst,label= 'First Fit',marker='^')
#
# NameError: name 'plt' is not defined

# %%
#Rifki depending on # of vertices
x = [11,21,31,41,51,61]
ychris = [1.076,1.094,1.102,1.099,1.108,1.099]
yfirst = [1.208,1.347,1.399,1.413,1.429,1.463]
yinsertion = [1.063,1.073,1.074,1.071,1.068,1.063]
yneighbor = [1.119,1.177,1.204,1.225,1.241,1.248]
ysavings = [1,1,1,1,1,1]

plt.plot(x,yinsertion,label ='Cheapest Insertion',marker= 's')
plt.plot(x,ychris, label='Christofides',marker='o')
plt.plot(x,yfirst,label= 'First Fit',marker='^')
plt.plot(x,yneighbor,label='Nearest Neighbour',marker='D')
plt.plot(x,ysavings,label='Savings',marker='X')

plt.xlabel('Number of vertices')
plt.ylabel('Result compared to best heuristic solution')
plt.xticks([11,21,31,41,51,61])

plt.legend()
plt.savefig('diagrammRifki.png')
plt.show()

# %%
#Rifki depending on # timesteps
x = [1,12,30,60,120]
ychris = [1.097,1.098,1.099,1.095,1.093]
yfirst = [1.407,1.398,1.386,1.363,1.329]
yinsertion = [1.076,1.074,1.068,1.064,1.060]
yneighbor = [1.222,1.215,1.205,1.193,1.176]
ysavings = [1,1,1,1,1]

plt.plot(x,yinsertion,label ='Cheapest Insertion',marker= 's')
plt.plot(x,ychris, label='Christofides',marker='o')
plt.plot(x,yfirst,label= 'First Fit',marker='^')
plt.plot(x,yneighbor,label='Nearest Neighbour',marker='D')
plt.plot(x,ysavings,label='Savings',marker='X')

plt.xlabel('Number of time steps')
plt.ylabel('Result compared to best heuristic solution')
plt.xticks([1,12,30,60,120])
plt.yticks([1.0,1.1,1.2,1.3,1.4])

plt.legend()
plt.savefig('diagrammRifkitimesteps.png')
plt.show()

# %%
# table TSPLIB
from tabulate import tabulate
table = [['Name','Size','Christofides','First Fit','Cheapest Insertion','Nearest Neighbor','Savings'],
         ['wi29','29','0.255986668','0.894141941','0.264645147','0.648516466','0.048799044'],
         ['dj38','38','0.194260817','1.568960337','0.454326923','1.543719952','0.061298077'],
         ['eil51','51','0.208920188','2.08201','0.377934272','2.389671362','0.063380282'],
         ['st70','70','0.143703704','4.051851852','0.586666667','2.862222222','0.112592593'],
         ['rat99','99','0.102394715','0.758876961','0.388109001','1.995871181','0.108175062'],
         ['kroA100','100','0.285170567','7.993186731','0.491072268','4.518748238','0.146367823'],
         ['lin105','105','0.291744906','1.536894082','0.494749287','2.138187635','0.092078726'],
         ['pr107','107','0.301875719','0.416518069','0.188971401','0.78188836','0.108367379'],
         ['qa194','194','0.363130881','3.229576561','0.36644568','3.475513259','0.099550898'],
        ]
print(tabulate(table,headers = 'firstrow',tablefmt = 'fancy_grid'))
# Out:
# ╒═════════╤════════╤════════════════╤═════════════╤══════════════════════╤════════════════════╤═══════════╕
# │ Name    │   Size │   Christofides │   First Fit │   Cheapest Insertion │   Nearest Neighbor │   Savings │
# ╞═════════╪════════╪════════════════╪═════════════╪══════════════════════╪════════════════════╪═══════════╡
# │ wi29    │     29 │       0.255987 │    0.894142 │             0.264645 │           0.648516 │ 0.048799  │
# ├─────────┼────────┼────────────────┼─────────────┼──────────────────────┼────────────────────┼───────────┤
# │ dj38    │     38 │       0.194261 │    1.56896  │             0.454327 │           1.54372  │ 0.0612981 │
# ├─────────┼────────┼────────────────┼─────────────┼──────────────────────┼────────────────────┼───────────┤
# │ eil51   │     51 │       0.20892  │    2.08201  │             0.377934 │           2.38967  │ 0.0633803 │
# ├─────────┼────────┼────────────────┼─────────────┼──────────────────────┼────────────────────┼───────────┤
# ...

# %%
#TSPLIB depending on # of vertices
x = [29,38,51,70,99,100,105,107,194]
ychris = [0.255987,0.194261, 0.20892,0.143704,0.102395, 0.285171, 0.291745, 0.301876,0.363131]
yfirst = [0.894142,1.568961,2.08201,4.05185,0.758877,7.99319,1.53689,0.416518,3.22958]
yinsertion = [0.264645,0.454327,0.377934 ,0.586667 ,0.388109 ,0.491072,0.494749,0.188971,0.366446]
yneighbor = [0.648516,1.54372 ,2.38967,2.86222 , 1.99587 ,4.51875, 2.13819 ,0.781888 ,3.47551 ]
ysavings = [0.048799,0.0612981 ,0.0633803,0.112593,0.108175 ,0.146368  ,0.0920787 ,0.108367,0.0995509]

plt.plot(x,yinsertion,label ='Cheapest Insertion',marker= 's')
plt.plot(x,ychris, label='Christofides',marker='o')
plt.plot(x,yfirst,label= 'First Fit',marker='^')
plt.plot(x,yneighbor,label='Nearest Neighbour',marker='D')
plt.plot(x,ysavings,label='Savings',marker='X')

plt.xlabel('Number of vertices')
plt.ylabel('Result compared to optimal solution')
plt.xticks([29,38,51,70,99,194])

plt.legend()
plt.savefig('FigureTSPLIB.png')
plt.show()

# %%
# table TSPLIB
from tabulate import tabulate
table = [['Number of vertices','Cheapest Insertion','Christofides','First Fit','Nearest Neighbor','Savings'],
         ['15','0.053129075','0.059992314','0.253594593','0.134638106','0.022779496'],
         ['20','0.040885366','0.071414153','0.280967278','0.072433853','0.011840036'],
         ['25','0.046432665','0.048044874','0.332725707','0.154337814','0.004124272'],
         ['30','0.04638889','0.03803072','0.265415916','0.12209557','0.001977983'],
         ['35','0.104242892','0.06997736','0.328312302','0.406717333','0'],
         ['40','0.038227031','0.060581036','0.366272924','0.154793502','0.001541555'],
        ]b
print(tabulate(table,headers = 'firstrow',tablefmt = 'fancy_grid'))
# Out:
# ╒══════════════════════╤══════════════════════╤════════════════╤═════════════╤════════════════════╤════════════╕
# │   Number of vertices │   Cheapest Insertion │   Christofides │   First Fit │   Nearest Neighbor │    Savings │
# ╞══════════════════════╪══════════════════════╪════════════════╪═════════════╪════════════════════╪════════════╡
# │                   15 │            0.0531291 │      0.0599923 │    0.253595 │          0.134638  │ 0.0227795  │
# ├──────────────────────┼──────────────────────┼────────────────┼─────────────┼────────────────────┼────────────┤
# │                   20 │            0.0408854 │      0.0714142 │    0.280967 │          0.0724339 │ 0.01184    │
# ├──────────────────────┼──────────────────────┼────────────────┼─────────────┼────────────────────┼────────────┤
# │                   25 │            0.0464327 │      0.0480449 │    0.332726 │          0.154338  │ 0.00412427 │
# ...

# %%
#TSPLIBs depending on # of vertices
x = [15,20,25,30,35,40]
ychris = [1.069623038,1.080991089,1.089520368,1.067851482,1.124127688,1.082983138]
yfirst = [1.54362555,1.78716961,2.020089925,2.178750204,2.908923249,2.526910251]
yinsertion = [1.23396097,1.232572095,1.361091985,1.328705579,2.642754192,1.513504086]
yneighbor = [1.119311892,1.177339835,1.203925058,1.225444005,1.240823055,1.247994397]
ysavings = [1.006955316,1.004005971,1.000930203,1.000542377,1,1.00028626]

plt.plot(x,yinsertion,label ='Cheapest Insertion',marker= 's')
plt.plot(x,ychris, label='Christofides',marker='o')
plt.plot(x,yfirst,label= 'First Fit',marker='^')
plt.plot(x,yneighbor,label='Nearest Neighbour',marker='D')
plt.plot(x,ysavings,label='Savings',marker='X')

plt.xlabel('Number of vertices')
plt.ylabel('Result compared to best heuristic solution')
plt.xticks([15,20,25,30,35,40])

plt.legend()
plt.savefig('diagrammCordeau.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# FIFO
x = (0,4,4.01,8,8.01,12)
y = (2,2,6,6,3,3)

plt.plot(x,y,'--', color='black', label='FIFO function')
#,linewidth = 0
plt.plot(x,y, color='black', label='Non-FIFO function')

plt.ylim(ymin=0,ymax =7)
plt.xlim(xmin=0,xmax =12)
plt.xlabel('Time',fontsize=14)
plt.ylabel('Travelling time',fontsize=14)
plt.grid()
plt.legend()
plt.savefig('FIFO.png')
plt.show()

# %%
# Melgarejo diagramm
string = '417 418 420 421 422 452 510 569 628 678 688 677 666 655 660 641 623 612 615 590 579 569 558 547 536 525 514 504 493 482 471 460 450 439 428 423 424 425 418 423 418 433 442 441 430 446 426 437 445 471 469 476 473 448 434 439 450 453 448 438 439 452 431 433 432 432 433 431 452 439 438 448 453 450 439 434 448 473 476 469 471 445 437 426 446 430 441 442 433 418 423 418 425 424 423 428 439 450 460 471 482 493 504 514 525 536 547 558 569 579 590 615 612 623 641 660 655 666 677 688 678 628 569 510 452 422 421 420 418 417'
numbers = [int(s) for s in string.split() if s.isdigit()]
x = np.arange(0,780,6).tolist()

plt.step(x,numbers, color='black')

#plt.ylim(ymin=0,ymax =700)
plt.xlim(xmin=0,xmax =780)
plt.xlabel('Time',fontsize=14)
plt.ylabel('Travel time',fontsize=14)
plt.xticks([0,195,390,585,780],['6:00','9:15','12:30','15:45','19:00'])
plt.grid()
plt.savefig('MelgarejoFunction.png')
plt.show()

# %%
# Rifki function
string6 = '239 297 251 260 297 288 285 276 321 284 294 279 264 261 303 256 300 302 297 292 271 267 283 339 306 300 282 318 294 319 337 294 350 294 331 333 313 337 324 365 367 323 385 276 327 289 290 297 268 315 343 321 306 278 282 342 355 332 307 260 342 255 272 281 284 297 275 272 269 308 338 309 316 224 337 280 318 335 297 293 333 310 276 287 329 268 296 328 314 333 354 318 310 306 316 359 377 320 388 306 310 314 315 336 330 325 301 317 326 305 305 261 264 312 317 335 275 226 305 283'
numbers6 = [int(s) for s in string6.split() if s.isdigit()]
x6 = np.arange(0,720,6).tolist()
string12 ='313 280 330 325 339 340 304 314 352 344 300 359 349 335 340 354 357 365 355 398 390 389 372 338 312 375 318 382 383 335 364 310 335 310 322 366 333 361 383 338 344 317 358 378 368 368 336 394 394 396 379 388 365 330 352 315 335 368 295 333'
numbers12 = [int(s) for s in string12.split() if s.isdigit()]
x12 = np.arange(0,720,12).tolist()
string24 = '324 337 358 329 379 371 369 352 412 412 409 379 383 397 399 380 342 374 360 416 346 395 392 406 404 397 363 388 378 349'
numbers24 = [int(s) for s in string24.split() if s.isdigit()]
x24 = np.arange(0,720,24).tolist()
string60 = '358 390 383 426 408 396 392 402 416 416 410 390' 
numbers60 = [int(s) for s in string60.split() if s.isdigit()]
x60 = np.arange(0,720,60).tolist()

plt.step(x6,numbers6, label='120 time steps')
plt.step(x12,numbers12, label='60 time steps')
plt.step(x24,numbers24, label='30 time steps')
plt.step(x60,numbers60, label='12 time steps')

plt.step([0,720],[418,418], label='1 time step')


#plt.ylim(ymin=0,ymax =700)
plt.xlim(xmin=0,xmax =720)
plt.xlabel('Time',fontsize=14)
plt.ylabel('Travel time',fontsize=14)
plt.xticks([0,180,360,540,720],['7:00','10:00','13:00','16:00','19:00'])
plt.grid()
plt.legend()
plt.savefig('RifkiFunction.png')
plt.show()

# %%
# Cordeau Function

string = '417 418 420 421 422 452 510 569 628 678 688 677 666 655 660 641 623 612 615 590 579 569 558 547 536 525 514 504 493 482 471 460 450 439 428 423 424 425 418 423 418 433 442 441 430 446 426 437 445 471 469 476 473 448 434 439 450 453 448 438 439 452 431 433 432 432 433 431 452 439 438 448 453 450 439 434 448 473 476 469 471 445 437 426 446 430 441 442 433 418 423 418 425 424 423 428 439 450 460 471 482 493 504 514 525 536 547 558 569 579 590 615 612 623 641 660 655 666 677 688 678 628 569 510 452 422 421 420 418 417'
numbers = [int(s) for s in string.split() if s.isdigit()]
x = np.arange(0,780,6).tolist()

plt.step(x,numbers, color='black', label='Travel time function')

#plt.ylim(ymin=0,ymax =700)
plt.xlim(xmin=0,xmax =780)
plt.xlabel('Time',fontsize=14)
plt.ylabel('Travel time',fontsize=14)
plt.xticks([0,195,390,585,780],['6:00','9:15','12:30','15:45','19:00'])
plt.grid()
plt.legend()
plt.savefig('CordeauFunction.png')
plt.show()
