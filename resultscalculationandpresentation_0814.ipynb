# %%
import re

filename = 'results_noTW.txt'
x = 0
sum_10 = 0
sum_20 = 0
sum_30 = 0
sum_50 = 0
sum_100 = 0

with open(filename) as f:
    for line in f:
        if('matrix10' not in line and 'matrix20' not in line):
            print(line)
            print(line[:7])
            if(line[:7] == 'inst_10' and line[:8] != 'inst_100'):
                numbers = re.findall(r"\d+",line)
                rightnumber = [int(e) for e in numbers if int(e) > 1000]
                print(rightnumber)
                sum_10 += rightnumber[0]

            if(line[:7] == 'inst_20'):
                numbers = re.findall(r"\d+",line)
                rightnumber = [int(e) for e in numbers if int(e) > 1000]
                print(rightnumber)
                sum_20 += rightnumber[0]

            if(line[:7] == 'inst_30'):
                numbers = re.findall(r"\d+",line)
                rightnumber = [int(e) for e in numbers if int(e) > 1000]
                print(rightnumber)
                sum_30 += rightnumber[0]

            if(line[:7] == 'inst_50'):
                numbers = re.findall(r"\d+",line)
                rightnumber = [int(e) for e in numbers if int(e) > 1000]
                print(rightnumber)
                sum_50 += rightnumber[0]

            if(line[:8] == 'inst_100'):
                numbers = re.findall(r"\d+",line)
                rightnumber = [int(e) for e in numbers if int(e) > 1000]
                print(rightnumber)
                sum_100 += rightnumber[0]
            
print(sum_10,sum_20,sum_30,sum_50,sum_100)
# Out:
# Optimal solutions are suffixed by *.
#
# Optimal
# If no solutions were found the objective value given is -1.
#
# If no s
#
#
#
#
# ____________________________ SIZE 10 ________________________________________
#
# _______
#
#
#
#
# inst_10_1.txt matrix00.txt 7605*
#
# inst_10
# [7605]
# inst_10_2.txt matrix00.txt 6854*
#
# inst_10
# [6854]
# inst_10_3.txt matrix00.txt 9206*
#
# inst_10
# [9206]
# inst_10_4.txt matrix00.txt 6594*
#
# inst_10
# [6594]
# inst_10_5.txt matrix00.txt 8692*
#
# inst_10
# [8692]
# inst_10_6.txt matrix00.txt 8700*
#
# inst_10
# [8700]
# inst_10_7.txt matrix00.txt 7340*
#
# inst_10
# [7340]
# inst_10_8.txt matrix00.txt 7571*
#
# inst_10
# [7571]
# inst_10_9.txt matrix00.txt 7890*
#
# inst_10
# [7890]
# inst_10_10.txt matrix00.txt 9002*
#
# inst_10
# [9002]
# inst_10_11.txt matrix00.txt 9231*
#
# inst_10
# [9231]
# inst_10_12.txt matrix00.txt 8293*
#
# inst_10
# [8293]
# inst_10_13.txt matrix00.txt 7189*
#
# inst_10
# [7189]
# inst_10_14.txt matrix00.txt 8912*
#
# inst_10
# [8912]
# inst_10_15.txt matrix00.txt 7366*
#
# inst_10
# [7366]
# inst_10_16.txt matrix00.txt 8156*
#
# inst_10
# [8156]
# inst_10_17.txt matrix00.txt 8673*
#
# inst_10
# [8673]
# inst_10_18.txt matrix00.txt 9167*
#
# inst_10
# [9167]
# inst_10_19.txt matrix00.txt 6335*
#
# inst_10
# [6335]
# inst_10_20.txt matrix00.txt 8144*
#
# inst_10
# [8144]
# inst_10_21.txt matrix00.txt 7952*
#
# inst_10
# [7952]
# inst_10_22.txt matrix00.txt 9106*
#
# inst_10
# [9106]
# inst_10_23.txt matrix00.txt 7040*
#
# inst_10
# [7040]
# inst_10_24.txt matrix00.txt 9210*
#
# inst_10
# [9210]
# inst_10_25.txt matrix00.txt 9539*
#
# inst_10
# [9539]
# inst_10_26.txt matrix00.txt 7958*
#
# inst_10
# [7958]
# inst_10_27.txt matrix00.txt 9305*
#
# inst_10
# [9305]
# inst_10_28.txt matrix00.txt 9545*
#
# inst_10
# [9545]
# inst_10_29.txt matrix00.txt 7291*
#
# inst_10
# [7291]
# inst_10_30.txt matrix00.txt 9497*
#
# inst_10
# [9497]
# inst_10_31.txt matrix00.txt 8373*
#
# inst_10
# [8373]
# inst_10_32.txt matrix00.txt 8660*
#
# inst_10
# [8660]
# inst_10_33.txt matrix00.txt 9014*
#
# inst_10
# [9014]
# inst_10_34.txt matrix00.txt 6690*
#
# inst_10
# [6690]
# inst_10_35.txt matrix00.txt 9044*
#
# inst_10
# [9044]
# inst_10_36.txt matrix00.txt 8358*
#
# inst_10
# [8358]
# inst_10_37.txt matrix00.txt 9700*
#
# inst_10
# [9700]
# inst_10_38.txt matrix00.txt 8262*
#
# inst_10
# [8262]
# inst_10_39.txt matrix00.txt 10103*
#
# inst_10
# [10103]
# inst_10_40.txt matrix00.txt 8977*
#
# inst_10
# [8977]
# inst_10_41.txt matrix00.txt 8618*
#
# inst_10
# [8618]
# inst_10_42.txt matrix00.txt 8417*
#
# inst_10
# [8417]
# inst_10_43.txt matrix00.txt 10301*
#
# inst_10
# [10301]
# inst_10_44.txt matrix00.txt 8132*
#
# inst_10
# [8132]
# inst_10_45.txt matrix00.txt 6850*
#
# inst_10
# [6850]
# inst_10_46.txt matrix00.txt 7553*
#
# inst_10
# [7553]
# inst_10_47.txt matrix00.txt 8935*
#
# inst_10
# [8935]
# inst_10_48.txt matrix00.txt 8543*
#
# inst_10
# [8543]
# inst_10_49.txt matrix00.txt 8116*
#
# inst_10
# [8116]
# inst_10_50.txt matrix00.txt 7545*
#
# inst_10
# [7545]
# inst_10_51.txt matrix00.txt 8845*
#
# inst_10
# [8845]
# inst_10_52.txt matrix00.txt 9022*
#
# inst_10
# [9022]
# inst_10_53.txt matrix00.txt 7105*
#
# inst_10
# [7105]
# inst_10_54.txt matrix00.txt 8348*
#
# inst_10
# [8348]
# inst_10_55.txt matrix00.txt 7090*
#
# inst_10
# [7090]
# inst_10_56.txt matrix00.txt 8942*
#
# inst_10
# [8942]
# inst_10_57.txt matrix00.txt 9210*
#
# inst_10
# [9210]
# inst_10_58.txt matrix00.txt 10045*
#
# inst_10
# [10045]
# inst_10_59.txt matrix00.txt 7292*
#
# inst_10
# [7292]
# inst_10_60.txt matrix00.txt 8834*
#
# inst_10
# [8834]
#
#
#
#
#
#
#
#
#
#
#
#
# ____________________________ SIZE 20 ________________________________________
#
# _______
#
#
#
#
# inst_20_1.txt matrix00.txt 12836*
#
# inst_20
# [12836]
# inst_20_2.txt matrix00.txt 13176*
#
# inst_20
# [13176]
# inst_20_3.txt matrix00.txt 13417*
#
# inst_20
# [13417]
# inst_20_4.txt matrix00.txt 13672*
#
# inst_20
# [13672]
# inst_20_5.txt matrix00.txt 13099*
#
# inst_20
# [13099]
# inst_20_6.txt matrix00.txt 12522*
#
# inst_20
# [12522]
# inst_20_7.txt matrix00.txt 13049*
#
# inst_20
# [13049]
# inst_20_8.txt matrix00.txt 12504*
#
# inst_20
# [12504]
# inst_20_9.txt matrix00.txt 13900*
#
# inst_20
# [13900]
# inst_20_10.txt matrix00.txt 13734*
#
# inst_20
# [13734]
# inst_20_11.txt matrix00.txt 13035*
#
# inst_20
# [13035]
# inst_20_12.txt matrix00.txt 13221*
#
# inst_20
# [13221]
# inst_20_13.txt matrix00.txt 11201*
#
# inst_20
# [11201]
# inst_20_14.txt matrix00.txt 11697*
#
# inst_20
# [11697]
# inst_20_15.txt matrix00.txt 13647*
#
# inst_20
# [13647]
# inst_20_16.txt matrix00.txt 11921*
#
# inst_20
# [11921]
# inst_20_17.txt matrix00.txt 13170*
#
# inst_20
# [13170]
# inst_20_18.txt matrix00.txt 12930*
#
# inst_20
# [12930]
# inst_20_19.txt matrix00.txt 12932*
#
# inst_20
# [12932]
# inst_20_20.txt matrix00.txt 13056*
#
# inst_20
# [13056]
# inst_20_21.txt matrix00.txt 12763*
#
# inst_20
# [12763]
# inst_20_22.txt matrix00.txt 13162*
#
# inst_20
# [13162]
# inst_20_23.txt matrix00.txt 13582*
#
# inst_20
# [13582]
# inst_20_24.txt matrix00.txt 13387*
#
# inst_20
# [13387]
# inst_20_25.txt matrix00.txt 13273*
#
# inst_20
# [13273]
# inst_20_26.txt matrix00.txt 12694*
#
# inst_20
# [12694]
# inst_20_27.txt matrix00.txt 10902*
#
# inst_20
# [10902]
# inst_20_28.txt matrix00.txt 13291*
#
# inst_20
# [13291]
# inst_20_29.txt matrix00.txt 13713*
#
# inst_20
# [13713]
# inst_20_30.txt matrix00.txt 13842*
#
# inst_20
# [13842]
# inst_20_31.txt matrix00.txt 12522*
#
# inst_20
# [12522]
# inst_20_32.txt matrix00.txt 13143*
#
# inst_20
# [13143]
# inst_20_33.txt matrix00.txt 13776*
#
# inst_20
# [13776]
# inst_20_34.txt matrix00.txt 11241*
#
# inst_20
# [11241]
# inst_20_35.txt matrix00.txt 14523*
#
# inst_20
# [14523]
# inst_20_36.txt matrix00.txt 11785*
#
# inst_20
# [11785]
# inst_20_37.txt matrix00.txt 13309*
#
# inst_20
# [13309]
# inst_20_38.txt matrix00.txt 13289*
#
# inst_20
# [13289]
# inst_20_39.txt matrix00.txt 13675*
#
# inst_20
# [13675]
# inst_20_40.txt matrix00.txt 12527*
#
# inst_20
# [12527]
# inst_20_41.txt matrix00.txt 11628*
#
# inst_20
# [11628]
# inst_20_42.txt matrix00.txt 14485*
#
# inst_20
# [14485]
# inst_20_43.txt matrix00.txt 12788*
#
# inst_20
# [12788]
# inst_20_44.txt matrix00.txt 13855*
#
# inst_20
# [13855]
# inst_20_45.txt matrix00.txt 12029*
#
# inst_20
# [12029]
# inst_20_46.txt matrix00.txt 13587*
#
# inst_20
# [13587]
# inst_20_47.txt matrix00.txt 13938*
#
# inst_20
# [13938]
# inst_20_48.txt matrix00.txt 13262
#
# inst_20
# [13262]
# inst_20_49.txt matrix00.txt 13307*
#
# inst_20
# [13307]
# inst_20_50.txt matrix00.txt 13850*
#
# inst_20
# [13850]
# inst_20_51.txt matrix00.txt 13076*
#
# inst_20
# [13076]
# inst_20_52.txt matrix00.txt 13692*
#
# inst_20
# [13692]
# inst_20_53.txt matrix00.txt 13239*
#
# inst_20
# [13239]
# inst_20_54.txt matrix00.txt 13202*
#
# inst_20
# [13202]
# inst_20_55.txt matrix00.txt 13825*
#
# inst_20
# [13825]
# inst_20_56.txt matrix00.txt 15052
#
# inst_20
# [15052]
# inst_20_57.txt matrix00.txt 11466*
#
# inst_20
# [11466]
# inst_20_58.txt matrix00.txt 13353*
#
# inst_20
# [13353]
# inst_20_59.txt matrix00.txt 13030*
#
# inst_20
# [13030]
# inst_20_60.txt matrix00.txt 12881*
#
# inst_20
# [12881]
#
#
#
#
#
#
#
#
#
#
#
#
# ____________________________ SIZE 30 ________________________________________
#
# _______
#
#
#
#
# inst_30_1.txt matrix00.txt 17167
#
# inst_30
# [17167]
# inst_30_2.txt matrix00.txt 15853
#
# inst_30
# [15853]
# inst_30_3.txt matrix00.txt 17202
#
# inst_30
# [17202]
# inst_30_4.txt matrix00.txt 15688
#
# inst_30
# [15688]
# inst_30_5.txt matrix00.txt 15022
#
# inst_30
# [15022]
# inst_30_6.txt matrix00.txt 17192
#
# inst_30
# [17192]
# inst_30_7.txt matrix00.txt 16056
#
# inst_30
# [16056]
# inst_30_8.txt matrix00.txt 17431
#
# inst_30
# [17431]
# inst_30_9.txt matrix00.txt 15963
#
# inst_30
# [15963]
# inst_30_10.txt matrix00.txt 16525
#
# inst_30
# [16525]
# inst_30_11.txt matrix00.txt 17434
#
# inst_30
# [17434]
# inst_30_12.txt matrix00.txt 17404
#
# inst_30
# [17404]
# inst_30_13.txt matrix00.txt 17576
#
# inst_30
# [17576]
# inst_30_14.txt matrix00.txt 18595
#
# inst_30
# [18595]
# inst_30_15.txt matrix00.txt 17313
#
# inst_30
# [17313]
# inst_30_16.txt matrix00.txt 14927
#
# inst_30
# [14927]
# inst_30_17.txt matrix00.txt 17188
#
# inst_30
# [17188]
# inst_30_18.txt matrix00.txt 17605
#
# inst_30
# [17605]
# inst_30_19.txt matrix00.txt 18397
#
# inst_30
# [18397]
# inst_30_20.txt matrix00.txt 16960
#
# inst_30
# [16960]
# inst_30_21.txt matrix00.txt 16711
#
# inst_30
# [16711]
# inst_30_22.txt matrix00.txt 17780
#
# inst_30
# [17780]
# inst_30_23.txt matrix00.txt 18611
#
# inst_30
# [18611]
# inst_30_24.txt matrix00.txt 18010
#
# inst_30
# [18010]
# inst_30_25.txt matrix00.txt 15366
#
# inst_30
# [15366]
# inst_30_26.txt matrix00.txt 16801
#
# inst_30
# [16801]
# inst_30_27.txt matrix00.txt 17913
#
# inst_30
# [17913]
# inst_30_28.txt matrix00.txt 17050
#
# inst_30
# [17050]
# inst_30_29.txt matrix00.txt 17996
#
# inst_30
# [17996]
# inst_30_30.txt matrix00.txt 17297
#
# inst_30
# [17297]
# inst_30_31.txt matrix00.txt 18099
#
# inst_30
# [18099]
# inst_30_32.txt matrix00.txt 17090
#
# inst_30
# [17090]
# inst_30_33.txt matrix00.txt 15275
#
# inst_30
# [15275]
# inst_30_34.txt matrix00.txt 15618
#
# inst_30
# [15618]
# inst_30_35.txt matrix00.txt 17330
#
# inst_30
# [17330]
# inst_30_36.txt matrix00.txt 17961
#
# inst_30
# [17961]
# inst_30_37.txt matrix00.txt 17289
#
# inst_30
# [17289]
# inst_30_38.txt matrix00.txt 16783
#
# inst_30
# [16783]
# inst_30_39.txt matrix00.txt 17329
#
# inst_30
# [17329]
# inst_30_40.txt matrix00.txt 18072
#
# inst_30
# [18072]
# inst_30_41.txt matrix00.txt 17272
#
# inst_30
# [17272]
# inst_30_42.txt matrix00.txt 17622
#
# inst_30
# [17622]
# inst_30_43.txt matrix00.txt 15714
#
# inst_30
# [15714]
# inst_30_44.txt matrix00.txt 17174
#
# inst_30
# [17174]
# inst_30_45.txt matrix00.txt 16220
#
# inst_30
# [16220]
# inst_30_46.txt matrix00.txt 17164
#
# inst_30
# [17164]
# inst_30_47.txt matrix00.txt 17524
#
# inst_30
# [17524]
# inst_30_48.txt matrix00.txt 18242
#
# inst_30
# [18242]
# inst_30_49.txt matrix00.txt 17715
#
# inst_30
# [17715]
# inst_30_50.txt matrix00.txt 17274
#
# inst_30
# [17274]
# inst_30_51.txt matrix00.txt 15375
#
# inst_30
# [15375]
# inst_30_52.txt matrix00.txt 16614
#
# inst_30
# [16614]
# inst_30_53.txt matrix00.txt 16828
#
# inst_30
# [16828]
# inst_30_54.txt matrix00.txt 17254
#
# inst_30
# [17254]
# inst_30_55.txt matrix00.txt 18057
#
# inst_30
# [18057]
# inst_30_56.txt matrix00.txt 17025
#
# inst_30
# [17025]
# inst_30_57.txt matrix00.txt 15630
#
# inst_30
# [15630]
# inst_30_58.txt matrix00.txt 16663
#
# inst_30
# [16663]
# inst_30_59.txt matrix00.txt 16677
#
# inst_30
# [16677]
# inst_30_60.txt matrix00.txt 16167
#
# inst_30
# [16167]
#
#
#
#
#
#
#
#
#
#
#
#
# ____________________________ SIZE 50 ________________________________________
#
# _______
#
#
#
#
# inst_50_1.txt matrix00.txt 22846
#
# inst_50
# [22846]
# inst_50_2.txt matrix00.txt 23713
#
# inst_50
# [23713]
# inst_50_3.txt matrix00.txt 22684
#
# inst_50
# [22684]
# inst_50_4.txt matrix00.txt 24833
#
# inst_50
# [24833]
# inst_50_5.txt matrix00.txt 20960
#
# inst_50
# [20960]
# inst_50_6.txt matrix00.txt 22396
#
# inst_50
# [22396]
# inst_50_7.txt matrix00.txt 23241
#
# inst_50
# [23241]
# inst_50_8.txt matrix00.txt 23274
#
# inst_50
# [23274]
# inst_50_9.txt matrix00.txt 22549
#
# inst_50
# [22549]
# inst_50_10.txt matrix00.txt 22831
#
# inst_50
# [22831]
# inst_50_11.txt matrix00.txt 23893
#
# inst_50
# [23893]
# inst_50_12.txt matrix00.txt 24610
#
# inst_50
# [24610]
# inst_50_13.txt matrix00.txt 23432
#
# inst_50
# [23432]
# inst_50_14.txt matrix00.txt 23678
#
# inst_50
# [23678]
# inst_50_15.txt matrix00.txt 22473
#
# inst_50
# [22473]
# inst_50_16.txt matrix00.txt 23538
#
# inst_50
# [23538]
# inst_50_17.txt matrix00.txt 24100
#
# inst_50
# [24100]
# inst_50_18.txt matrix00.txt 21539
#
# inst_50
# [21539]
# inst_50_19.txt matrix00.txt 24477
#
# inst_50
# [24477]
# inst_50_20.txt matrix00.txt 23170
#
# inst_50
# [23170]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ____________________________ SIZE 100 ________________________________________
#
# _______
#
#
#
#
# inst_100_1.txt matrix00.txt 39249
#
# inst_10
# [39249]
# inst_100_2.txt matrix00.txt 36015
#
# inst_10
# [36015]
# inst_100_3.txt matrix00.txt 36807
#
# inst_10
# [36807]
# inst_100_4.txt matrix00.txt 39631
#
# inst_10
# [39631]
# inst_100_5.txt matrix00.txt 37377
#
# inst_10
# [37377]
# inst_100_6.txt matrix00.txt 38312
#
# inst_10
# [38312]
# inst_100_7.txt matrix00.txt 40371
#
# inst_10
# [40371]
# inst_100_8.txt matrix00.txt 39302
#
# inst_10
# [39302]
# inst_100_9.txt matrix00.txt 38189
#
# inst_10
# [38189]
# inst_100_10.txt matrix00.txt 40021
#
# inst_10
# [40021]
# inst_100_11.txt matrix00.txt 40486
#
# inst_10
# [40486]
# inst_100_12.txt matrix00.txt 41122
#
# inst_10
# [41122]
# inst_100_13.txt matrix00.txt 39439
#
# inst_10
# [39439]
# inst_100_14.txt matrix00.txt 38089
#
# inst_10
# [38089]
# inst_100_15.txt matrix00.txt 39826
#
# inst_10
# [39826]
# inst_100_16.txt matrix00.txt 39128
#
# inst_10
# [39128]
# inst_100_17.txt matrix00.txt 41595
#
# inst_10
# [41595]
# inst_100_18.txt matrix00.txt 39582
#
# inst_10
# [39582]
# inst_100_19.txt matrix00.txt 40032
#
# inst_10
# [40032]
# inst_100_20.txt matrix00.txt 40163
#
# inst_10
# [40163]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 502287 784663 1020090 464237 784736
